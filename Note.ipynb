# %%
import pandas as pd 
from datetime import datetime as dt

# %%
data_file_name = 'HistoricalQuotes.csv'
tsdf = pd.read_csv(data_file_name, parse_dates=True,index_col='Date') 
tsdf.head()
# Out:
#              Close/Last     Volume    Open    High     Low
# Date
# 2020-02-28       273.36  106721200  257.26  278.41  256.37
# 2020-02-27       273.52   80151380  281.10  286.00  272.96
# 2020-02-26       292.65   49678430  286.53  297.88  286.50
# 2020-02-25       288.08   57668360  300.95  302.53  286.13
# 2020-02-24       298.18   55548830  297.26  304.18  289.23

# %%
# dt.strptime('2017-02-22','%y-%m-%d')
tsdf.loc['2020-02'].head()
# Out:
#              Close/Last     Volume    Open    High     Low
# Date
# 2020-02-28       273.36  106721200  257.26  278.41  256.37
# 2020-02-27       273.52   80151380  281.10  286.00  272.96
# 2020-02-26       292.65   49678430  286.53  297.88  286.50
# 2020-02-25       288.08   57668360  300.95  302.53  286.13
# 2020-02-24       298.18   55548830  297.26  304.18  289.23

# %%
mean = tsdf.resample('M').mean()

# %%
mean.plot(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
len(tsdf)
# Out:
# 2518
